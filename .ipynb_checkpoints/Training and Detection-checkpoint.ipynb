# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet_stopsign' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# !pip install tensorflow==2.13.0
# Out:
# Requirement already satisfied: tensorflow==2.13.0 in ./tfod/lib/python3.9/site-packages (2.13.0)
# Requirement already satisfied: tensorflow-macos==2.13.0 in ./tfod/lib/python3.9/site-packages (from tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.3.0)
# Requirement already satisfied: packaging in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.20.3)
# Requirement already satisfied: setuptools in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (49.2.1)
# Requirement already satisfied: six>=1.12.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.60.1)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./tfod/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in ./tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in ./tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./tfod/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./tfod/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./tfod/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./tfod/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in ./tfod/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./tfod/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./tfod/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./tfod/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./tfod/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./tfod/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in ./tfod/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.17.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./tfod/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./tfod/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow==2.13.0) (3.2.2)

# %%
# !pip install tf-models-official
# Out:
# Requirement already satisfied: tf-models-official in ./tfod/lib/python3.9/site-packages (2.5.1)
# Requirement already satisfied: Cython in ./tfod/lib/python3.9/site-packages (from tf-models-official) (3.0.8)
# Requirement already satisfied: Pillow in ./tfod/lib/python3.9/site-packages (from tf-models-official) (10.2.0)
# Requirement already satisfied: gin-config in ./tfod/lib/python3.9/site-packages (from tf-models-official) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in ./tfod/lib/python3.9/site-packages (from tf-models-official) (2.118.0)
# Requirement already satisfied: kaggle>=1.3.9 in ./tfod/lib/python3.9/site-packages (from tf-models-official) (1.6.6)
# Requirement already satisfied: matplotlib in ./tfod/lib/python3.9/site-packages (from tf-models-official) (3.8.3)
# Requirement already satisfied: numpy>=1.15.4 in ./tfod/lib/python3.9/site-packages (from tf-models-official) (1.24.3)
# Requirement already satisfied: oauth2client in ./tfod/lib/python3.9/site-packages (from tf-models-official) (4.1.3)
# Requirement already satisfied: opencv-python-headless in ./tfod/lib/python3.9/site-packages (from tf-models-official) (4.9.0.80)
# Requirement already satisfied: pandas>=0.22.0 in ./tfod/lib/python3.9/site-packages (from tf-models-official) (2.2.0)
# Requirement already satisfied: psutil>=5.4.3 in ./tfod/lib/python3.9/site-packages (from tf-models-official) (5.9.8)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in ./tfod/lib/python3.9/site-packages (from tf-models-official) (9.0.0)
# Requirement already satisfied: pycocotools in ./tfod/lib/python3.9/site-packages (from tf-models-official) (2.0.7)
# Requirement already satisfied: pyyaml>=5.1 in ./tfod/lib/python3.9/site-packages (from tf-models-official) (5.3.1)
# Requirement already satisfied: sacrebleu in ./tfod/lib/python3.9/site-packages (from tf-models-official) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in ./tfod/lib/python3.9/site-packages (from tf-models-official) (1.12.0)
# Requirement already satisfied: sentencepiece in ./tfod/lib/python3.9/site-packages (from tf-models-official) (0.2.0)
# Requirement already satisfied: seqeval in ./tfod/lib/python3.9/site-packages (from tf-models-official) (1.2.2)
# Requirement already satisfied: six in ./tfod/lib/python3.9/site-packages (from tf-models-official) (1.16.0)
# Requirement already satisfied: tensorflow-addons in ./tfod/lib/python3.9/site-packages (from tf-models-official) (0.23.0)
# Requirement already satisfied: tensorflow-datasets in ./tfod/lib/python3.9/site-packages (from tf-models-official) (4.9.3)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in ./tfod/lib/python3.9/site-packages (from tf-models-official) (0.16.1)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in ./tfod/lib/python3.9/site-packages (from tf-models-official) (0.8.0)
# Requirement already satisfied: tensorflow>=2.5.0 in ./tfod/lib/python3.9/site-packages (from tf-models-official) (2.13.0)
# Requirement already satisfied: tf-slim>=1.1.0 in ./tfod/lib/python3.9/site-packages (from tf-models-official) (1.1.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in ./tfod/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in ./tfod/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official) (2.28.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in ./tfod/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in ./tfod/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official) (2.17.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in ./tfod/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official) (4.1.1)
# Requirement already satisfied: certifi in ./tfod/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official) (2024.2.2)
# Requirement already satisfied: python-dateutil in ./tfod/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official) (2.8.2)
# Requirement already satisfied: requests in ./tfod/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official) (2.31.0)
# Requirement already satisfied: tqdm in ./tfod/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official) (4.66.2)
# Requirement already satisfied: python-slugify in ./tfod/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official) (8.0.4)
# Requirement already satisfied: urllib3 in ./tfod/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official) (2.2.1)
# Requirement already satisfied: bleach in ./tfod/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official) (6.1.0)
# Requirement already satisfied: pytz>=2020.1 in ./tfod/lib/python3.9/site-packages (from pandas>=0.22.0->tf-models-official) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./tfod/lib/python3.9/site-packages (from pandas>=0.22.0->tf-models-official) (2024.1)
# Requirement already satisfied: tensorflow-macos==2.13.0 in ./tfod/lib/python3.9/site-packages (from tensorflow>=2.5.0->tf-models-official) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (3.3.0)
# Requirement already satisfied: packaging in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (3.20.3)
# Requirement already satisfied: setuptools in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (49.2.1)
# Requirement already satisfied: termcolor>=1.1.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (1.60.1)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in ./tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (2.13.1)
# Requirement already satisfied: tf-keras>=2.14.1 in ./tfod/lib/python3.9/site-packages (from tensorflow-hub>=0.6.0->tf-models-official) (2.15.0)
# Requirement already satisfied: dm-tree~=0.1.1 in ./tfod/lib/python3.9/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official) (0.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in ./tfod/lib/python3.9/site-packages (from matplotlib->tf-models-official) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./tfod/lib/python3.9/site-packages (from matplotlib->tf-models-official) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./tfod/lib/python3.9/site-packages (from matplotlib->tf-models-official) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./tfod/lib/python3.9/site-packages (from matplotlib->tf-models-official) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in ./tfod/lib/python3.9/site-packages (from matplotlib->tf-models-official) (2.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./tfod/lib/python3.9/site-packages (from matplotlib->tf-models-official) (6.1.1)
# Requirement already satisfied: pyasn1>=0.1.7 in ./tfod/lib/python3.9/site-packages (from oauth2client->tf-models-official) (0.5.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in ./tfod/lib/python3.9/site-packages (from oauth2client->tf-models-official) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in ./tfod/lib/python3.9/site-packages (from oauth2client->tf-models-official) (4.9)
# Requirement already satisfied: portalocker in ./tfod/lib/python3.9/site-packages (from sacrebleu->tf-models-official) (2.8.2)
# Requirement already satisfied: regex in ./tfod/lib/python3.9/site-packages (from sacrebleu->tf-models-official) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in ./tfod/lib/python3.9/site-packages (from sacrebleu->tf-models-official) (0.9.0)
# Requirement already satisfied: colorama in ./tfod/lib/python3.9/site-packages (from sacrebleu->tf-models-official) (0.4.6)
# Requirement already satisfied: lxml in ./tfod/lib/python3.9/site-packages (from sacrebleu->tf-models-official) (5.1.0)
# Requirement already satisfied: scikit-learn>=0.21.3 in ./tfod/lib/python3.9/site-packages (from seqeval->tf-models-official) (1.4.1.post1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in ./tfod/lib/python3.9/site-packages (from tensorflow-addons->tf-models-official) (2.13.3)
# Requirement already satisfied: array-record in ./tfod/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official) (0.4.1)
# Requirement already satisfied: click in ./tfod/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official) (8.1.7)
# Requirement already satisfied: etils>=0.9.0 in ./tfod/lib/python3.9/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official) (1.5.2)
# Requirement already satisfied: promise in ./tfod/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official) (2.3)
# Requirement already satisfied: tensorflow-metadata in ./tfod/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official) (1.14.0)
# Requirement already satisfied: toml in ./tfod/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official) (0.10.2)
# Requirement already satisfied: fsspec in ./tfod/lib/python3.9/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official) (2024.2.0)
# Requirement already satisfied: zipp in ./tfod/lib/python3.9/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official) (3.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./tfod/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official) (1.62.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./tfod/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official) (5.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./tfod/lib/python3.9/site-packages (from requests->kaggle>=1.3.9->tf-models-official) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./tfod/lib/python3.9/site-packages (from requests->kaggle>=1.3.9->tf-models-official) (3.6)
# Requirement already satisfied: joblib>=1.2.0 in ./tfod/lib/python3.9/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./tfod/lib/python3.9/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official) (3.3.0)
# Requirement already satisfied: webencodings in ./tfod/lib/python3.9/site-packages (from bleach->kaggle>=1.3.9->tf-models-official) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in ./tfod/lib/python3.9/site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official) (1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./tfod/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (0.42.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in ./tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (3.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./tfod/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in ./tfod/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (7.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./tfod/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (2.1.5)
# Requirement already satisfied: oauthlib>=3.0.0 in ./tfod/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official) (3.2.2)

# %%
# !pip install pyyaml==5.3.1
# Out:
# Requirement already satisfied: pyyaml==5.3.1 in ./tfod/lib/python3.9/site-packages (5.3.1)

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !pip install protobuf==3.20.3
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# Requirement already satisfied: protobuf==3.20.3 in ./tfod/lib/python3.9/site-packages (3.20.3)
# Processing /Users/alexis/Desktop/ObjectDetector/Tensorflow/models/research
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: avro-python3 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (2.54.0)
# Requirement already satisfied: pillow in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (10.2.0)
# Requirement already satisfied: lxml in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (5.1.0)
# Requirement already satisfied: matplotlib in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (3.8.3)
# Requirement already satisfied: Cython in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (3.0.8)
# Requirement already satisfied: contextlib2 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (2.0.7)
# Requirement already satisfied: lvis in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (1.12.0)
# Requirement already satisfied: pandas in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: tf-models-official>=2.5.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (2.5.1)
# Requirement already satisfied: tensorflow_io in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (0.36.0)
# Requirement already satisfied: keras in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (2.13.1)
# Requirement already satisfied: pyparsing==2.4.7 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: portalocker in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2.8.2)
# Requirement already satisfied: regex in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.24.3)
# Requirement already satisfied: colorama in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: gin-config in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.118.0)
# Requirement already satisfied: kaggle>=1.3.9 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.6.6)
# Requirement already satisfied: oauth2client in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.9.0.80)
# Requirement already satisfied: psutil>=5.4.3 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.8)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (9.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.3.1)
# Requirement already satisfied: sentencepiece in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: seqeval in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: tensorflow-addons in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.23.0)
# Requirement already satisfied: tensorflow-datasets in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.9.3)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.16.1)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.8.0)
# Requirement already satisfied: tensorflow>=2.5.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from pandas->object-detection==0.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from pandas->object-detection==0.1) (2024.1)
# Requirement already satisfied: absl-py>=0.2.2 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (3.9.14)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.9.4)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.60.1)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Requirement already satisfied: js2py<1,>=0.74 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.74)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (4.21.1)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (3.0.3)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.7.0)
# Requirement already satisfied: packaging>=22.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (23.2)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (4.6.1)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.23.0)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<4.26.0,>=3.20.3 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (4.5.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Requirement already satisfied: pyarrow<15.0.0,>=3.0.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix<1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from apache-beam->object-detection==0.1) (0.6)
# Requirement already satisfied: cycler>=0.10.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from lvis->object-detection==0.1) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.1.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from lvis->object-detection==0.1) (1.4.5)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from lvis->object-detection==0.1) (4.9.0.80)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (4.49.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from matplotlib->object-detection==0.1) (6.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.36.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow_io->object-detection==0.1) (0.36.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.28.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.17.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: docopt in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->object-detection==0.1) (3.17.0)
# Requirement already satisfied: tzlocal>=1.2 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from js2py<1,>=0.74->apache-beam->object-detection==0.1) (5.2)
# Requirement already satisfied: pyjsparser>=2.5.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from js2py<1,>=0.74->apache-beam->object-detection==0.1) (2.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (0.18.0)
# Requirement already satisfied: certifi in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2024.2.2)
# Requirement already satisfied: tqdm in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.66.2)
# Requirement already satisfied: python-slugify in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.4)
# Requirement already satisfied: urllib3 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.2.1)
# Requirement already satisfied: bleach in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1) (2.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.6)
# Requirement already satisfied: tensorflow-macos==2.13.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (2.13.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (49.2.1)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (2.13.0)
# Requirement already satisfied: tf-keras>=2.14.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-hub>=0.6.0->tf-models-official>=2.5.1->object-detection==0.1) (2.15.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.5.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.4.1.post1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.13.3)
# Requirement already satisfied: array-record in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.4.1)
# Requirement already satisfied: click in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.1.7)
# Requirement already satisfied: etils>=0.9.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.5.2)
# Requirement already satisfied: promise in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.14.0)
# Requirement already satisfied: toml in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: fsspec in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2024.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.62.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.3.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: webencodings in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from bleach->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (0.42.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (7.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.0->tensorflow>=2.5.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1656835 sha256=d49618edd4c041bac3a6acf2d422bea0592ee37cee825418d3e4c331d2356651
#   Stored in directory: /private/var/folders/96/js1p33753k7gkmscxgsp7tq80000gn/T/pip-ephem-wheel-cache-z069s74w/wheels/aa/1d/ba/c297f8292f2f70c19e3e90a2fffb67676d8553e6de5520730c
# Successfully built object-detection
# Installing collected packages: object-detection
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# Successfully installed object-detection-0.1

# %% [markdown]
# ### Note: If you encounter the error ModuleNotFoundError: No module named 'tensorflow.python.keras.layers.preprocessing' when running the cell below, please modify line #31 in tfod/lib/python(version)/site-packages/official/vision/image_classification/augment.py to the following: `from tensorflow.keras.preprocessing import image as image_ops`

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# Running tests under Python 3.9.1: /Users/alexis/Desktop/ObjectDetector/tfod/bin/python
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0221 14:27:53.968826 8087821376 batch_normalization.py:1531] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/object_detection/builders/model_builder.py:1112: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0221 14:27:54.087156 8087821376 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.28s
# I0221 14:27:54.224510 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.28s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.32s
# I0221 14:27:54.539912 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.32s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.21s
# I0221 14:27:54.751632 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.21s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.13s
# I0221 14:27:54.886452 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.13s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 0.9s
# I0221 14:27:55.790497 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 0.9s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0221 14:27:55.792064 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.01s
# I0221 14:27:55.802958 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0221 14:27:55.810359 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I0221 14:27:55.818022 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.05s
# I0221 14:27:55.863458 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.05s
# I0221 14:27:55.910902 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.05s
# I0221 14:27:55.959969 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.05s
# I0221 14:27:56.008832 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.05s
# I0221 14:27:56.058079 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.05s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# I0221 14:27:56.073552 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0221 14:27:56.163340 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0221 14:27:56.163419 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 64
# I0221 14:27:56.163444 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 3
# I0221 14:27:56.164499 8087821376 efficientnet_model.py:147] round_filter input=32 output=32
# I0221 14:27:56.175335 8087821376 efficientnet_model.py:147] round_filter input=32 output=32
# I0221 14:27:56.175387 8087821376 efficientnet_model.py:147] round_filter input=16 output=16
# I0221 14:27:56.207977 8087821376 efficientnet_model.py:147] round_filter input=16 output=16
# I0221 14:27:56.208046 8087821376 efficientnet_model.py:147] round_filter input=24 output=24
# I0221 14:27:56.297353 8087821376 efficientnet_model.py:147] round_filter input=24 output=24
# I0221 14:27:56.297425 8087821376 efficientnet_model.py:147] round_filter input=40 output=40
# I0221 14:27:56.380986 8087821376 efficientnet_model.py:147] round_filter input=40 output=40
# I0221 14:27:56.381066 8087821376 efficientnet_model.py:147] round_filter input=80 output=80
# I0221 14:27:56.586136 8087821376 efficientnet_model.py:147] round_filter input=80 output=80
# I0221 14:27:56.586215 8087821376 efficientnet_model.py:147] round_filter input=112 output=112
# I0221 14:27:56.709098 8087821376 efficientnet_model.py:147] round_filter input=112 output=112
# I0221 14:27:56.709175 8087821376 efficientnet_model.py:147] round_filter input=192 output=192
# I0221 14:27:56.877459 8087821376 efficientnet_model.py:147] round_filter input=192 output=192
# I0221 14:27:56.877527 8087821376 efficientnet_model.py:147] round_filter input=320 output=320
# I0221 14:27:56.918866 8087821376 efficientnet_model.py:147] round_filter input=1280 output=1280
# I0221 14:27:56.942069 8087821376 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0221 14:27:56.967751 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0221 14:27:56.967821 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 88
# I0221 14:27:56.967846 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 4
# I0221 14:27:56.968688 8087821376 efficientnet_model.py:147] round_filter input=32 output=32
# I0221 14:27:56.976969 8087821376 efficientnet_model.py:147] round_filter input=32 output=32
# I0221 14:27:56.977046 8087821376 efficientnet_model.py:147] round_filter input=16 output=16
# I0221 14:27:57.053135 8087821376 efficientnet_model.py:147] round_filter input=16 output=16
# I0221 14:27:57.053211 8087821376 efficientnet_model.py:147] round_filter input=24 output=24
# I0221 14:27:57.171637 8087821376 efficientnet_model.py:147] round_filter input=24 output=24
# I0221 14:27:57.171715 8087821376 efficientnet_model.py:147] round_filter input=40 output=40
# I0221 14:27:57.284936 8087821376 efficientnet_model.py:147] round_filter input=40 output=40
# I0221 14:27:57.285008 8087821376 efficientnet_model.py:147] round_filter input=80 output=80
# I0221 14:27:57.438452 8087821376 efficientnet_model.py:147] round_filter input=80 output=80
# I0221 14:27:57.438526 8087821376 efficientnet_model.py:147] round_filter input=112 output=112
# I0221 14:27:57.594052 8087821376 efficientnet_model.py:147] round_filter input=112 output=112
# I0221 14:27:57.594127 8087821376 efficientnet_model.py:147] round_filter input=192 output=192
# I0221 14:27:57.797625 8087821376 efficientnet_model.py:147] round_filter input=192 output=192
# I0221 14:27:57.797698 8087821376 efficientnet_model.py:147] round_filter input=320 output=320
# I0221 14:27:57.890864 8087821376 efficientnet_model.py:147] round_filter input=1280 output=1280
# I0221 14:27:57.911142 8087821376 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0221 14:27:57.942979 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0221 14:27:57.943055 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 112
# I0221 14:27:57.943107 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 5
# I0221 14:27:57.944006 8087821376 efficientnet_model.py:147] round_filter input=32 output=32
# I0221 14:27:57.952098 8087821376 efficientnet_model.py:147] round_filter input=32 output=32
# I0221 14:27:57.952172 8087821376 efficientnet_model.py:147] round_filter input=16 output=16
# I0221 14:27:58.018290 8087821376 efficientnet_model.py:147] round_filter input=16 output=16
# I0221 14:27:58.018371 8087821376 efficientnet_model.py:147] round_filter input=24 output=24
# I0221 14:27:58.137686 8087821376 efficientnet_model.py:147] round_filter input=24 output=24
# I0221 14:27:58.137763 8087821376 efficientnet_model.py:147] round_filter input=40 output=48
# I0221 14:27:58.256733 8087821376 efficientnet_model.py:147] round_filter input=40 output=48
# I0221 14:27:58.256809 8087821376 efficientnet_model.py:147] round_filter input=80 output=88
# I0221 14:27:58.415483 8087821376 efficientnet_model.py:147] round_filter input=80 output=88
# I0221 14:27:58.415557 8087821376 efficientnet_model.py:147] round_filter input=112 output=120
# I0221 14:27:58.576236 8087821376 efficientnet_model.py:147] round_filter input=112 output=120
# I0221 14:27:58.576314 8087821376 efficientnet_model.py:147] round_filter input=192 output=208
# I0221 14:27:58.785902 8087821376 efficientnet_model.py:147] round_filter input=192 output=208
# I0221 14:27:58.785984 8087821376 efficientnet_model.py:147] round_filter input=320 output=352
# I0221 14:27:58.881286 8087821376 efficientnet_model.py:147] round_filter input=1280 output=1408
# I0221 14:27:58.902593 8087821376 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0221 14:27:58.933043 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0221 14:27:58.933119 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 160
# I0221 14:27:58.933145 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 6
# I0221 14:27:58.933953 8087821376 efficientnet_model.py:147] round_filter input=32 output=40
# I0221 14:27:58.942791 8087821376 efficientnet_model.py:147] round_filter input=32 output=40
# I0221 14:27:58.942864 8087821376 efficientnet_model.py:147] round_filter input=16 output=24
# I0221 14:27:59.009176 8087821376 efficientnet_model.py:147] round_filter input=16 output=24
# I0221 14:27:59.009252 8087821376 efficientnet_model.py:147] round_filter input=24 output=32
# I0221 14:27:59.223190 8087821376 efficientnet_model.py:147] round_filter input=24 output=32
# I0221 14:27:59.223264 8087821376 efficientnet_model.py:147] round_filter input=40 output=48
# I0221 14:27:59.338051 8087821376 efficientnet_model.py:147] round_filter input=40 output=48
# I0221 14:27:59.338124 8087821376 efficientnet_model.py:147] round_filter input=80 output=96
# I0221 14:27:59.534021 8087821376 efficientnet_model.py:147] round_filter input=80 output=96
# I0221 14:27:59.534091 8087821376 efficientnet_model.py:147] round_filter input=112 output=136
# I0221 14:27:59.735327 8087821376 efficientnet_model.py:147] round_filter input=112 output=136
# I0221 14:27:59.735399 8087821376 efficientnet_model.py:147] round_filter input=192 output=232
# I0221 14:27:59.987724 8087821376 efficientnet_model.py:147] round_filter input=192 output=232
# I0221 14:27:59.987803 8087821376 efficientnet_model.py:147] round_filter input=320 output=384
# I0221 14:28:00.085929 8087821376 efficientnet_model.py:147] round_filter input=1280 output=1536
# I0221 14:28:00.108548 8087821376 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0221 14:28:00.141973 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0221 14:28:00.142053 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 224
# I0221 14:28:00.142077 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 7
# I0221 14:28:00.142874 8087821376 efficientnet_model.py:147] round_filter input=32 output=48
# I0221 14:28:00.151642 8087821376 efficientnet_model.py:147] round_filter input=32 output=48
# I0221 14:28:00.151700 8087821376 efficientnet_model.py:147] round_filter input=16 output=24
# I0221 14:28:00.216101 8087821376 efficientnet_model.py:147] round_filter input=16 output=24
# I0221 14:28:00.216178 8087821376 efficientnet_model.py:147] round_filter input=24 output=32
# I0221 14:28:00.368165 8087821376 efficientnet_model.py:147] round_filter input=24 output=32
# I0221 14:28:00.368243 8087821376 efficientnet_model.py:147] round_filter input=40 output=56
# I0221 14:28:00.525902 8087821376 efficientnet_model.py:147] round_filter input=40 output=56
# I0221 14:28:00.525974 8087821376 efficientnet_model.py:147] round_filter input=80 output=112
# I0221 14:28:00.758426 8087821376 efficientnet_model.py:147] round_filter input=80 output=112
# I0221 14:28:00.758503 8087821376 efficientnet_model.py:147] round_filter input=112 output=160
# I0221 14:28:00.999375 8087821376 efficientnet_model.py:147] round_filter input=112 output=160
# I0221 14:28:00.999451 8087821376 efficientnet_model.py:147] round_filter input=192 output=272
# I0221 14:28:01.344813 8087821376 efficientnet_model.py:147] round_filter input=192 output=272
# I0221 14:28:01.344890 8087821376 efficientnet_model.py:147] round_filter input=320 output=448
# I0221 14:28:01.447078 8087821376 efficientnet_model.py:147] round_filter input=1280 output=1792
# I0221 14:28:01.473489 8087821376 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0221 14:28:01.513243 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0221 14:28:01.513317 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 288
# I0221 14:28:01.513344 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 7
# I0221 14:28:01.514152 8087821376 efficientnet_model.py:147] round_filter input=32 output=48
# I0221 14:28:01.521802 8087821376 efficientnet_model.py:147] round_filter input=32 output=48
# I0221 14:28:01.521847 8087821376 efficientnet_model.py:147] round_filter input=16 output=24
# I0221 14:28:01.612173 8087821376 efficientnet_model.py:147] round_filter input=16 output=24
# I0221 14:28:01.612245 8087821376 efficientnet_model.py:147] round_filter input=24 output=40
# I0221 14:28:01.802289 8087821376 efficientnet_model.py:147] round_filter input=24 output=40
# I0221 14:28:01.802366 8087821376 efficientnet_model.py:147] round_filter input=40 output=64
# I0221 14:28:01.997306 8087821376 efficientnet_model.py:147] round_filter input=40 output=64
# I0221 14:28:01.997381 8087821376 efficientnet_model.py:147] round_filter input=80 output=128
# I0221 14:28:02.386579 8087821376 efficientnet_model.py:147] round_filter input=80 output=128
# I0221 14:28:02.386650 8087821376 efficientnet_model.py:147] round_filter input=112 output=176
# I0221 14:28:02.671736 8087821376 efficientnet_model.py:147] round_filter input=112 output=176
# I0221 14:28:02.671813 8087821376 efficientnet_model.py:147] round_filter input=192 output=304
# I0221 14:28:03.069583 8087821376 efficientnet_model.py:147] round_filter input=192 output=304
# I0221 14:28:03.069659 8087821376 efficientnet_model.py:147] round_filter input=320 output=512
# I0221 14:28:03.233472 8087821376 efficientnet_model.py:147] round_filter input=1280 output=2048
# I0221 14:28:03.257789 8087821376 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0221 14:28:03.303481 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0221 14:28:03.303557 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I0221 14:28:03.303581 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I0221 14:28:03.304394 8087821376 efficientnet_model.py:147] round_filter input=32 output=56
# I0221 14:28:03.313277 8087821376 efficientnet_model.py:147] round_filter input=32 output=56
# I0221 14:28:03.313350 8087821376 efficientnet_model.py:147] round_filter input=16 output=32
# I0221 14:28:03.408602 8087821376 efficientnet_model.py:147] round_filter input=16 output=32
# I0221 14:28:03.408679 8087821376 efficientnet_model.py:147] round_filter input=24 output=40
# I0221 14:28:03.639060 8087821376 efficientnet_model.py:147] round_filter input=24 output=40
# I0221 14:28:03.639134 8087821376 efficientnet_model.py:147] round_filter input=40 output=72
# I0221 14:28:03.873530 8087821376 efficientnet_model.py:147] round_filter input=40 output=72
# I0221 14:28:03.873607 8087821376 efficientnet_model.py:147] round_filter input=80 output=144
# I0221 14:28:04.191747 8087821376 efficientnet_model.py:147] round_filter input=80 output=144
# I0221 14:28:04.191827 8087821376 efficientnet_model.py:147] round_filter input=112 output=200
# I0221 14:28:04.519054 8087821376 efficientnet_model.py:147] round_filter input=112 output=200
# I0221 14:28:04.519132 8087821376 efficientnet_model.py:147] round_filter input=192 output=344
# I0221 14:28:05.025213 8087821376 efficientnet_model.py:147] round_filter input=192 output=344
# I0221 14:28:05.025289 8087821376 efficientnet_model.py:147] round_filter input=320 output=576
# I0221 14:28:05.202362 8087821376 efficientnet_model.py:147] round_filter input=1280 output=2304
# I0221 14:28:05.229286 8087821376 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0221 14:28:05.281780 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0221 14:28:05.281854 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I0221 14:28:05.281881 8087821376 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I0221 14:28:05.282687 8087821376 efficientnet_model.py:147] round_filter input=32 output=64
# I0221 14:28:05.291331 8087821376 efficientnet_model.py:147] round_filter input=32 output=64
# I0221 14:28:05.291393 8087821376 efficientnet_model.py:147] round_filter input=16 output=32
# I0221 14:28:05.416981 8087821376 efficientnet_model.py:147] round_filter input=16 output=32
# I0221 14:28:05.417054 8087821376 efficientnet_model.py:147] round_filter input=24 output=48
# I0221 14:28:05.811636 8087821376 efficientnet_model.py:147] round_filter input=24 output=48
# I0221 14:28:05.811716 8087821376 efficientnet_model.py:147] round_filter input=40 output=80
# I0221 14:28:06.079794 8087821376 efficientnet_model.py:147] round_filter input=40 output=80
# I0221 14:28:06.079869 8087821376 efficientnet_model.py:147] round_filter input=80 output=160
# I0221 14:28:06.474993 8087821376 efficientnet_model.py:147] round_filter input=80 output=160
# I0221 14:28:06.475077 8087821376 efficientnet_model.py:147] round_filter input=112 output=224
# I0221 14:28:06.890660 8087821376 efficientnet_model.py:147] round_filter input=112 output=224
# I0221 14:28:06.890734 8087821376 efficientnet_model.py:147] round_filter input=192 output=384
# I0221 14:28:07.499974 8087821376 efficientnet_model.py:147] round_filter input=192 output=384
# I0221 14:28:07.500062 8087821376 efficientnet_model.py:147] round_filter input=320 output=640
# I0221 14:28:07.750761 8087821376 efficientnet_model.py:147] round_filter input=1280 output=2560
# I0221 14:28:07.779484 8087821376 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 11.77s
# I0221 14:28:07.842821 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 11.77s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0221 14:28:07.851267 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0221 14:28:07.852097 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0221 14:28:07.852272 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0221 14:28:07.852933 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0221 14:28:07.853531 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0221 14:28:07.853672 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0221 14:28:07.854145 8087821376 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 13.909s
#
# OK (skipped=1)

# %%
#!pip install tensorflow --upgrade

# %%
#!pip uninstall protobuf matplotlib -y
#!pip install protobuf matplotlib==3.2

# %%
import object_detection

# %%
# !brew install wget
# Out:
# ==> Downloading https://formulae.brew.sh/api/formula.jws.json
# ######################################################################### 100.0%
# ==> Downloading https://formulae.brew.sh/api/cask.jws.json
# ######################################################################### 100.0%
# Warning: wget 1.21.4 is already installed and up-to-date.
# To reinstall 1.21.4, run:
#   brew reinstall wget

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# --2024-02-21 14:28:13--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.251.46.187, 142.251.214.155, 142.250.189.219, ...
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.251.46.187|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  13.4MB/s    in 1.5s
#
# 2024-02-21 14:28:15 (13.4 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'StopSign', 'id':1}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
#ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
#if os.path.exists(ARCHIVE_FILES):
#  !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}

# %% [markdown]
# # 5. Update Config for Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 4e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.01
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.997
#          scale: true
#          epsilon: 0.001
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 4e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.01
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.997
#            scale: true
#            epsilon: 0.001
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.6
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 1e-08
#        iou_threshold: 0.6
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.08
#          total_steps: 50000
#          warmup_learning_rate: 0.026666
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.9
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=5000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet_stopsign --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet_stopsign/pipeline.config --num_train_steps=5000

# %%
# !{command}
# Out:
# /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# I0221 14:28:52.786866 8087821376 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 5000
# I0221 14:28:52.795002 8087821376 config_util.py:552] Maybe overwriting train_steps: 5000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0221 14:28:52.795087 8087821376 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0221 14:28:52.805945 8087821376 deprecation.py:364] From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0221 14:28:52.808889 8087821376 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0221 14:28:52.808948 8087821376 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0221 14:28:52.808972 8087821376 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0221 14:28:52.808993 8087821376 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0221 14:28:52.812674 8087821376 deprecation.py:364] From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0221 14:28:52.823310 8087821376 deprecation.py:364] From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0221 14:28:56.013562 8087821376 deprecation.py:364] From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0221 14:28:57.410394 8087821376 deprecation.py:364] From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0221 14:28:58.115994 8087821376 deprecation.py:364] From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2024-02-21 14:28:59.524036: W tensorflow/core/framework/dataset.cc:956] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0221 14:29:02.438946 11962183680 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0221 14:29:05.882847 11962183680 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0221 14:29:08.768595 11962183680 deprecation.py:569] From /Users/alexis/Desktop/ObjectDetector/tfod/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0221 14:29:09.213021 11962183680 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0221 14:29:11.573847 11962183680 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0221 14:29:13.507363 11962183680 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0221 14:29:15.778074 11968737280 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 100 per-step time 0.438s
# I0221 14:29:52.130217 8087821376 model_lib_v2.py:705] Step 100 per-step time 0.438s
# INFO:tensorflow:{'Loss/classification_loss': 0.2652269,
#  'Loss/localization_loss': 0.24708807,
#  'Loss/regularization_loss': 0.15394163,
#  'Loss/total_loss': 0.6662566,
#  'learning_rate': 0.0319994}
# I0221 14:29:52.130860 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.2652269,
#  'Loss/localization_loss': 0.24708807,
#  'Loss/regularization_loss': 0.15394163,
#  'Loss/total_loss': 0.6662566,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.348s
# I0221 14:30:26.894581 8087821376 model_lib_v2.py:705] Step 200 per-step time 0.348s
# INFO:tensorflow:{'Loss/classification_loss': 0.15964946,
#  'Loss/localization_loss': 0.21478559,
#  'Loss/regularization_loss': 0.15386055,
#  'Loss/total_loss': 0.5282956,
#  'learning_rate': 0.0373328}
# I0221 14:30:26.895109 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.15964946,
#  'Loss/localization_loss': 0.21478559,
#  'Loss/regularization_loss': 0.15386055,
#  'Loss/total_loss': 0.5282956,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.393s
# I0221 14:31:06.232945 8087821376 model_lib_v2.py:705] Step 300 per-step time 0.393s
# INFO:tensorflow:{'Loss/classification_loss': 0.1981602,
#  'Loss/localization_loss': 0.049272135,
#  'Loss/regularization_loss': 0.15366393,
#  'Loss/total_loss': 0.40109628,
#  'learning_rate': 0.0426662}
# I0221 14:31:06.233546 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.1981602,
#  'Loss/localization_loss': 0.049272135,
#  'Loss/regularization_loss': 0.15366393,
#  'Loss/total_loss': 0.40109628,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.377s
# I0221 14:31:43.940954 8087821376 model_lib_v2.py:705] Step 400 per-step time 0.377s
# INFO:tensorflow:{'Loss/classification_loss': 0.14943369,
#  'Loss/localization_loss': 0.17966531,
#  'Loss/regularization_loss': 0.1534539,
#  'Loss/total_loss': 0.4825529,
#  'learning_rate': 0.047999598}
# I0221 14:31:43.941573 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.14943369,
#  'Loss/localization_loss': 0.17966531,
#  'Loss/regularization_loss': 0.1534539,
#  'Loss/total_loss': 0.4825529,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.374s
# I0221 14:32:21.302355 8087821376 model_lib_v2.py:705] Step 500 per-step time 0.374s
# INFO:tensorflow:{'Loss/classification_loss': 0.07903664,
#  'Loss/localization_loss': 0.03668992,
#  'Loss/regularization_loss': 0.15315755,
#  'Loss/total_loss': 0.26888412,
#  'learning_rate': 0.053333}
# I0221 14:32:21.302923 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.07903664,
#  'Loss/localization_loss': 0.03668992,
#  'Loss/regularization_loss': 0.15315755,
#  'Loss/total_loss': 0.26888412,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.347s
# I0221 14:32:56.039642 8087821376 model_lib_v2.py:705] Step 600 per-step time 0.347s
# INFO:tensorflow:{'Loss/classification_loss': 0.14408764,
#  'Loss/localization_loss': 0.09649002,
#  'Loss/regularization_loss': 0.15282013,
#  'Loss/total_loss': 0.3933978,
#  'learning_rate': 0.0586664}
# I0221 14:32:56.040328 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.14408764,
#  'Loss/localization_loss': 0.09649002,
#  'Loss/regularization_loss': 0.15282013,
#  'Loss/total_loss': 0.3933978,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.357s
# I0221 14:33:31.790184 8087821376 model_lib_v2.py:705] Step 700 per-step time 0.357s
# INFO:tensorflow:{'Loss/classification_loss': 0.05947423,
#  'Loss/localization_loss': 0.03659837,
#  'Loss/regularization_loss': 0.1523229,
#  'Loss/total_loss': 0.2483955,
#  'learning_rate': 0.0639998}
# I0221 14:33:31.790774 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.05947423,
#  'Loss/localization_loss': 0.03659837,
#  'Loss/regularization_loss': 0.1523229,
#  'Loss/total_loss': 0.2483955,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.370s
# I0221 14:34:08.812187 8087821376 model_lib_v2.py:705] Step 800 per-step time 0.370s
# INFO:tensorflow:{'Loss/classification_loss': 0.094451234,
#  'Loss/localization_loss': 0.07648879,
#  'Loss/regularization_loss': 0.15181686,
#  'Loss/total_loss': 0.3227569,
#  'learning_rate': 0.069333196}
# I0221 14:34:08.812726 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.094451234,
#  'Loss/localization_loss': 0.07648879,
#  'Loss/regularization_loss': 0.15181686,
#  'Loss/total_loss': 0.3227569,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.368s
# I0221 14:34:45.625336 8087821376 model_lib_v2.py:705] Step 900 per-step time 0.368s
# INFO:tensorflow:{'Loss/classification_loss': 0.110560924,
#  'Loss/localization_loss': 0.079564646,
#  'Loss/regularization_loss': 0.15136845,
#  'Loss/total_loss': 0.34149402,
#  'learning_rate': 0.074666604}
# I0221 14:34:45.625928 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.110560924,
#  'Loss/localization_loss': 0.079564646,
#  'Loss/regularization_loss': 0.15136845,
#  'Loss/total_loss': 0.34149402,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.372s
# I0221 14:35:22.826476 8087821376 model_lib_v2.py:705] Step 1000 per-step time 0.372s
# INFO:tensorflow:{'Loss/classification_loss': 0.1274319,
#  'Loss/localization_loss': 0.054550976,
#  'Loss/regularization_loss': 0.15080993,
#  'Loss/total_loss': 0.3327928,
#  'learning_rate': 0.08}
# I0221 14:35:22.827098 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.1274319,
#  'Loss/localization_loss': 0.054550976,
#  'Loss/regularization_loss': 0.15080993,
#  'Loss/total_loss': 0.3327928,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.364s
# I0221 14:35:59.228075 8087821376 model_lib_v2.py:705] Step 1100 per-step time 0.364s
# INFO:tensorflow:{'Loss/classification_loss': 0.17238773,
#  'Loss/localization_loss': 0.07441654,
#  'Loss/regularization_loss': 0.15010169,
#  'Loss/total_loss': 0.396906,
#  'learning_rate': 0.07999918}
# I0221 14:35:59.228773 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.17238773,
#  'Loss/localization_loss': 0.07441654,
#  'Loss/regularization_loss': 0.15010169,
#  'Loss/total_loss': 0.396906,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.371s
# I0221 14:36:36.318109 8087821376 model_lib_v2.py:705] Step 1200 per-step time 0.371s
# INFO:tensorflow:{'Loss/classification_loss': 0.06597848,
#  'Loss/localization_loss': 0.067683145,
#  'Loss/regularization_loss': 0.14940748,
#  'Loss/total_loss': 0.2830691,
#  'learning_rate': 0.079996705}
# I0221 14:36:36.318696 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.06597848,
#  'Loss/localization_loss': 0.067683145,
#  'Loss/regularization_loss': 0.14940748,
#  'Loss/total_loss': 0.2830691,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.372s
# I0221 14:37:13.482528 8087821376 model_lib_v2.py:705] Step 1300 per-step time 0.372s
# INFO:tensorflow:{'Loss/classification_loss': 0.060539722,
#  'Loss/localization_loss': 0.039024256,
#  'Loss/regularization_loss': 0.14872347,
#  'Loss/total_loss': 0.24828744,
#  'learning_rate': 0.0799926}
# I0221 14:37:13.483148 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.060539722,
#  'Loss/localization_loss': 0.039024256,
#  'Loss/regularization_loss': 0.14872347,
#  'Loss/total_loss': 0.24828744,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.397s
# I0221 14:37:53.164912 8087821376 model_lib_v2.py:705] Step 1400 per-step time 0.397s
# INFO:tensorflow:{'Loss/classification_loss': 0.116935834,
#  'Loss/localization_loss': 0.034364484,
#  'Loss/regularization_loss': 0.14798433,
#  'Loss/total_loss': 0.29928467,
#  'learning_rate': 0.07998685}
# I0221 14:37:53.165511 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.116935834,
#  'Loss/localization_loss': 0.034364484,
#  'Loss/regularization_loss': 0.14798433,
#  'Loss/total_loss': 0.29928467,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.367s
# I0221 14:38:29.894284 8087821376 model_lib_v2.py:705] Step 1500 per-step time 0.367s
# INFO:tensorflow:{'Loss/classification_loss': 0.078709416,
#  'Loss/localization_loss': 0.024259722,
#  'Loss/regularization_loss': 0.14723057,
#  'Loss/total_loss': 0.2501997,
#  'learning_rate': 0.07997945}
# I0221 14:38:29.894901 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.078709416,
#  'Loss/localization_loss': 0.024259722,
#  'Loss/regularization_loss': 0.14723057,
#  'Loss/total_loss': 0.2501997,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.356s
# I0221 14:39:05.549916 8087821376 model_lib_v2.py:705] Step 1600 per-step time 0.356s
# INFO:tensorflow:{'Loss/classification_loss': 0.12336881,
#  'Loss/localization_loss': 0.033071224,
#  'Loss/regularization_loss': 0.14664422,
#  'Loss/total_loss': 0.30308425,
#  'learning_rate': 0.079970405}
# I0221 14:39:05.550521 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.12336881,
#  'Loss/localization_loss': 0.033071224,
#  'Loss/regularization_loss': 0.14664422,
#  'Loss/total_loss': 0.30308425,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.404s
# I0221 14:39:45.945391 8087821376 model_lib_v2.py:705] Step 1700 per-step time 0.404s
# INFO:tensorflow:{'Loss/classification_loss': 0.10937015,
#  'Loss/localization_loss': 0.047202528,
#  'Loss/regularization_loss': 0.14588518,
#  'Loss/total_loss': 0.30245787,
#  'learning_rate': 0.07995972}
# I0221 14:39:45.946063 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.10937015,
#  'Loss/localization_loss': 0.047202528,
#  'Loss/regularization_loss': 0.14588518,
#  'Loss/total_loss': 0.30245787,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.377s
# I0221 14:40:23.648142 8087821376 model_lib_v2.py:705] Step 1800 per-step time 0.377s
# INFO:tensorflow:{'Loss/classification_loss': 0.10236678,
#  'Loss/localization_loss': 0.04293553,
#  'Loss/regularization_loss': 0.14535348,
#  'Loss/total_loss': 0.2906558,
#  'learning_rate': 0.0799474}
# I0221 14:40:23.648746 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.10236678,
#  'Loss/localization_loss': 0.04293553,
#  'Loss/regularization_loss': 0.14535348,
#  'Loss/total_loss': 0.2906558,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.362s
# I0221 14:40:59.837970 8087821376 model_lib_v2.py:705] Step 1900 per-step time 0.362s
# INFO:tensorflow:{'Loss/classification_loss': 0.05197308,
#  'Loss/localization_loss': 0.032352988,
#  'Loss/regularization_loss': 0.14509757,
#  'Loss/total_loss': 0.22942363,
#  'learning_rate': 0.07993342}
# I0221 14:40:59.838551 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.05197308,
#  'Loss/localization_loss': 0.032352988,
#  'Loss/regularization_loss': 0.14509757,
#  'Loss/total_loss': 0.22942363,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.347s
# I0221 14:41:34.502419 8087821376 model_lib_v2.py:705] Step 2000 per-step time 0.347s
# INFO:tensorflow:{'Loss/classification_loss': 0.03993821,
#  'Loss/localization_loss': 0.020866144,
#  'Loss/regularization_loss': 0.14440733,
#  'Loss/total_loss': 0.20521168,
#  'learning_rate': 0.07991781}
# I0221 14:41:34.503033 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.03993821,
#  'Loss/localization_loss': 0.020866144,
#  'Loss/regularization_loss': 0.14440733,
#  'Loss/total_loss': 0.20521168,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.360s
# I0221 14:42:10.502330 8087821376 model_lib_v2.py:705] Step 2100 per-step time 0.360s
# INFO:tensorflow:{'Loss/classification_loss': 0.046128698,
#  'Loss/localization_loss': 0.014353005,
#  'Loss/regularization_loss': 0.14363809,
#  'Loss/total_loss': 0.2041198,
#  'learning_rate': 0.07990056}
# I0221 14:42:10.502967 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.046128698,
#  'Loss/localization_loss': 0.014353005,
#  'Loss/regularization_loss': 0.14363809,
#  'Loss/total_loss': 0.2041198,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.378s
# I0221 14:42:48.285249 8087821376 model_lib_v2.py:705] Step 2200 per-step time 0.378s
# INFO:tensorflow:{'Loss/classification_loss': 0.05883866,
#  'Loss/localization_loss': 0.022283295,
#  'Loss/regularization_loss': 0.14283441,
#  'Loss/total_loss': 0.22395638,
#  'learning_rate': 0.07988167}
# I0221 14:42:48.285851 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.05883866,
#  'Loss/localization_loss': 0.022283295,
#  'Loss/regularization_loss': 0.14283441,
#  'Loss/total_loss': 0.22395638,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.362s
# I0221 14:43:24.520885 8087821376 model_lib_v2.py:705] Step 2300 per-step time 0.362s
# INFO:tensorflow:{'Loss/classification_loss': 0.0521513,
#  'Loss/localization_loss': 0.019918263,
#  'Loss/regularization_loss': 0.14209628,
#  'Loss/total_loss': 0.21416584,
#  'learning_rate': 0.07986114}
# I0221 14:43:24.521553 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.0521513,
#  'Loss/localization_loss': 0.019918263,
#  'Loss/regularization_loss': 0.14209628,
#  'Loss/total_loss': 0.21416584,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.400s
# I0221 14:44:04.568785 8087821376 model_lib_v2.py:705] Step 2400 per-step time 0.400s
# INFO:tensorflow:{'Loss/classification_loss': 0.04493116,
#  'Loss/localization_loss': 0.014237607,
#  'Loss/regularization_loss': 0.14132413,
#  'Loss/total_loss': 0.2004929,
#  'learning_rate': 0.07983897}
# I0221 14:44:04.569482 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.04493116,
#  'Loss/localization_loss': 0.014237607,
#  'Loss/regularization_loss': 0.14132413,
#  'Loss/total_loss': 0.2004929,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.412s
# I0221 14:44:45.785135 8087821376 model_lib_v2.py:705] Step 2500 per-step time 0.412s
# INFO:tensorflow:{'Loss/classification_loss': 0.054293096,
#  'Loss/localization_loss': 0.01593098,
#  'Loss/regularization_loss': 0.14056516,
#  'Loss/total_loss': 0.21078923,
#  'learning_rate': 0.079815164}
# I0221 14:44:45.785861 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.054293096,
#  'Loss/localization_loss': 0.01593098,
#  'Loss/regularization_loss': 0.14056516,
#  'Loss/total_loss': 0.21078923,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.364s
# I0221 14:45:22.222579 8087821376 model_lib_v2.py:705] Step 2600 per-step time 0.364s
# INFO:tensorflow:{'Loss/classification_loss': 0.035843827,
#  'Loss/localization_loss': 0.009769738,
#  'Loss/regularization_loss': 0.13982643,
#  'Loss/total_loss': 0.18544,
#  'learning_rate': 0.07978972}
# I0221 14:45:22.223240 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.035843827,
#  'Loss/localization_loss': 0.009769738,
#  'Loss/regularization_loss': 0.13982643,
#  'Loss/total_loss': 0.18544,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.392s
# I0221 14:46:01.381314 8087821376 model_lib_v2.py:705] Step 2700 per-step time 0.392s
# INFO:tensorflow:{'Loss/classification_loss': 0.08748764,
#  'Loss/localization_loss': 0.023683166,
#  'Loss/regularization_loss': 0.13911198,
#  'Loss/total_loss': 0.25028276,
#  'learning_rate': 0.07976264}
# I0221 14:46:01.381914 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.08748764,
#  'Loss/localization_loss': 0.023683166,
#  'Loss/regularization_loss': 0.13911198,
#  'Loss/total_loss': 0.25028276,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.390s
# I0221 14:46:40.367048 8087821376 model_lib_v2.py:705] Step 2800 per-step time 0.390s
# INFO:tensorflow:{'Loss/classification_loss': 0.04880738,
#  'Loss/localization_loss': 0.019288521,
#  'Loss/regularization_loss': 0.13837758,
#  'Loss/total_loss': 0.20647348,
#  'learning_rate': 0.07973392}
# I0221 14:46:40.367737 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.04880738,
#  'Loss/localization_loss': 0.019288521,
#  'Loss/regularization_loss': 0.13837758,
#  'Loss/total_loss': 0.20647348,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.393s
# I0221 14:47:19.674498 8087821376 model_lib_v2.py:705] Step 2900 per-step time 0.393s
# INFO:tensorflow:{'Loss/classification_loss': 0.08755978,
#  'Loss/localization_loss': 0.017180307,
#  'Loss/regularization_loss': 0.13762257,
#  'Loss/total_loss': 0.24236266,
#  'learning_rate': 0.07970358}
# I0221 14:47:19.675484 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.08755978,
#  'Loss/localization_loss': 0.017180307,
#  'Loss/regularization_loss': 0.13762257,
#  'Loss/total_loss': 0.24236266,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.375s
# I0221 14:47:57.148570 8087821376 model_lib_v2.py:705] Step 3000 per-step time 0.375s
# INFO:tensorflow:{'Loss/classification_loss': 0.040201016,
#  'Loss/localization_loss': 0.027158309,
#  'Loss/regularization_loss': 0.13692917,
#  'Loss/total_loss': 0.2042885,
#  'learning_rate': 0.0796716}
# I0221 14:47:57.149274 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.040201016,
#  'Loss/localization_loss': 0.027158309,
#  'Loss/regularization_loss': 0.13692917,
#  'Loss/total_loss': 0.2042885,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.389s
# I0221 14:48:36.044091 8087821376 model_lib_v2.py:705] Step 3100 per-step time 0.389s
# INFO:tensorflow:{'Loss/classification_loss': 0.039311804,
#  'Loss/localization_loss': 0.014697335,
#  'Loss/regularization_loss': 0.13616168,
#  'Loss/total_loss': 0.19017081,
#  'learning_rate': 0.07963799}
# I0221 14:48:36.044794 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.039311804,
#  'Loss/localization_loss': 0.014697335,
#  'Loss/regularization_loss': 0.13616168,
#  'Loss/total_loss': 0.19017081,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.416s
# I0221 14:49:17.625012 8087821376 model_lib_v2.py:705] Step 3200 per-step time 0.416s
# INFO:tensorflow:{'Loss/classification_loss': 0.03086101,
#  'Loss/localization_loss': 0.021500133,
#  'Loss/regularization_loss': 0.1354075,
#  'Loss/total_loss': 0.18776864,
#  'learning_rate': 0.07960275}
# I0221 14:49:17.625735 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.03086101,
#  'Loss/localization_loss': 0.021500133,
#  'Loss/regularization_loss': 0.1354075,
#  'Loss/total_loss': 0.18776864,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.396s
# I0221 14:49:57.264081 8087821376 model_lib_v2.py:705] Step 3300 per-step time 0.396s
# INFO:tensorflow:{'Loss/classification_loss': 0.038116295,
#  'Loss/localization_loss': 0.025405988,
#  'Loss/regularization_loss': 0.13518041,
#  'Loss/total_loss': 0.1987027,
#  'learning_rate': 0.07956588}
# I0221 14:49:57.264725 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.038116295,
#  'Loss/localization_loss': 0.025405988,
#  'Loss/regularization_loss': 0.13518041,
#  'Loss/total_loss': 0.1987027,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.372s
# I0221 14:50:34.452749 8087821376 model_lib_v2.py:705] Step 3400 per-step time 0.372s
# INFO:tensorflow:{'Loss/classification_loss': 0.07426888,
#  'Loss/localization_loss': 0.031565093,
#  'Loss/regularization_loss': 0.13529456,
#  'Loss/total_loss': 0.24112853,
#  'learning_rate': 0.079527386}
# I0221 14:50:34.453412 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.07426888,
#  'Loss/localization_loss': 0.031565093,
#  'Loss/regularization_loss': 0.13529456,
#  'Loss/total_loss': 0.24112853,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.368s
# I0221 14:51:11.250950 8087821376 model_lib_v2.py:705] Step 3500 per-step time 0.368s
# INFO:tensorflow:{'Loss/classification_loss': 0.032131888,
#  'Loss/localization_loss': 0.01457436,
#  'Loss/regularization_loss': 0.13464774,
#  'Loss/total_loss': 0.181354,
#  'learning_rate': 0.07948727}
# I0221 14:51:11.251608 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.032131888,
#  'Loss/localization_loss': 0.01457436,
#  'Loss/regularization_loss': 0.13464774,
#  'Loss/total_loss': 0.181354,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.383s
# I0221 14:51:49.577152 8087821376 model_lib_v2.py:705] Step 3600 per-step time 0.383s
# INFO:tensorflow:{'Loss/classification_loss': 0.03520713,
#  'Loss/localization_loss': 0.029163226,
#  'Loss/regularization_loss': 0.13393416,
#  'Loss/total_loss': 0.19830452,
#  'learning_rate': 0.079445526}
# I0221 14:51:49.577864 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.03520713,
#  'Loss/localization_loss': 0.029163226,
#  'Loss/regularization_loss': 0.13393416,
#  'Loss/total_loss': 0.19830452,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.372s
# I0221 14:52:26.791934 8087821376 model_lib_v2.py:705] Step 3700 per-step time 0.372s
# INFO:tensorflow:{'Loss/classification_loss': 0.03833785,
#  'Loss/localization_loss': 0.010627811,
#  'Loss/regularization_loss': 0.1332124,
#  'Loss/total_loss': 0.18217805,
#  'learning_rate': 0.07940216}
# I0221 14:52:26.792598 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.03833785,
#  'Loss/localization_loss': 0.010627811,
#  'Loss/regularization_loss': 0.1332124,
#  'Loss/total_loss': 0.18217805,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.389s
# I0221 14:53:05.730247 8087821376 model_lib_v2.py:705] Step 3800 per-step time 0.389s
# INFO:tensorflow:{'Loss/classification_loss': 0.035082486,
#  'Loss/localization_loss': 0.025229875,
#  'Loss/regularization_loss': 0.1325145,
#  'Loss/total_loss': 0.19282687,
#  'learning_rate': 0.079357184}
# I0221 14:53:05.730893 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.035082486,
#  'Loss/localization_loss': 0.025229875,
#  'Loss/regularization_loss': 0.1325145,
#  'Loss/total_loss': 0.19282687,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.367s
# I0221 14:53:42.423199 8087821376 model_lib_v2.py:705] Step 3900 per-step time 0.367s
# INFO:tensorflow:{'Loss/classification_loss': 0.06491643,
#  'Loss/localization_loss': 0.03145089,
#  'Loss/regularization_loss': 0.13177173,
#  'Loss/total_loss': 0.22813904,
#  'learning_rate': 0.07931058}
# I0221 14:53:42.423851 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.06491643,
#  'Loss/localization_loss': 0.03145089,
#  'Loss/regularization_loss': 0.13177173,
#  'Loss/total_loss': 0.22813904,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.353s
# I0221 14:54:17.691519 8087821376 model_lib_v2.py:705] Step 4000 per-step time 0.353s
# INFO:tensorflow:{'Loss/classification_loss': 0.03240445,
#  'Loss/localization_loss': 0.015153049,
#  'Loss/regularization_loss': 0.13107799,
#  'Loss/total_loss': 0.1786355,
#  'learning_rate': 0.07926236}
# I0221 14:54:17.692178 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.03240445,
#  'Loss/localization_loss': 0.015153049,
#  'Loss/regularization_loss': 0.13107799,
#  'Loss/total_loss': 0.1786355,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.386s
# I0221 14:54:56.312520 8087821376 model_lib_v2.py:705] Step 4100 per-step time 0.386s
# INFO:tensorflow:{'Loss/classification_loss': 0.030749982,
#  'Loss/localization_loss': 0.01055218,
#  'Loss/regularization_loss': 0.13033438,
#  'Loss/total_loss': 0.17163654,
#  'learning_rate': 0.07921253}
# I0221 14:54:56.313212 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.030749982,
#  'Loss/localization_loss': 0.01055218,
#  'Loss/regularization_loss': 0.13033438,
#  'Loss/total_loss': 0.17163654,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.375s
# I0221 14:55:33.797882 8087821376 model_lib_v2.py:705] Step 4200 per-step time 0.375s
# INFO:tensorflow:{'Loss/classification_loss': 0.06600821,
#  'Loss/localization_loss': 0.021566164,
#  'Loss/regularization_loss': 0.12964985,
#  'Loss/total_loss': 0.21722423,
#  'learning_rate': 0.07916109}
# I0221 14:55:33.798592 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.06600821,
#  'Loss/localization_loss': 0.021566164,
#  'Loss/regularization_loss': 0.12964985,
#  'Loss/total_loss': 0.21722423,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.366s
# I0221 14:56:10.439344 8087821376 model_lib_v2.py:705] Step 4300 per-step time 0.366s
# INFO:tensorflow:{'Loss/classification_loss': 0.023359919,
#  'Loss/localization_loss': 0.0066401814,
#  'Loss/regularization_loss': 0.12893213,
#  'Loss/total_loss': 0.15893224,
#  'learning_rate': 0.07910804}
# I0221 14:56:10.439972 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.023359919,
#  'Loss/localization_loss': 0.0066401814,
#  'Loss/regularization_loss': 0.12893213,
#  'Loss/total_loss': 0.15893224,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.380s
# I0221 14:56:48.475258 8087821376 model_lib_v2.py:705] Step 4400 per-step time 0.380s
# INFO:tensorflow:{'Loss/classification_loss': 0.02208981,
#  'Loss/localization_loss': 0.011095206,
#  'Loss/regularization_loss': 0.12820584,
#  'Loss/total_loss': 0.16139086,
#  'learning_rate': 0.07905338}
# I0221 14:56:48.475913 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.02208981,
#  'Loss/localization_loss': 0.011095206,
#  'Loss/regularization_loss': 0.12820584,
#  'Loss/total_loss': 0.16139086,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.363s
# I0221 14:57:24.818468 8087821376 model_lib_v2.py:705] Step 4500 per-step time 0.363s
# INFO:tensorflow:{'Loss/classification_loss': 0.035520628,
#  'Loss/localization_loss': 0.009906717,
#  'Loss/regularization_loss': 0.12749986,
#  'Loss/total_loss': 0.17292722,
#  'learning_rate': 0.07899711}
# I0221 14:57:24.819109 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.035520628,
#  'Loss/localization_loss': 0.009906717,
#  'Loss/regularization_loss': 0.12749986,
#  'Loss/total_loss': 0.17292722,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.359s
# I0221 14:58:00.729522 8087821376 model_lib_v2.py:705] Step 4600 per-step time 0.359s
# INFO:tensorflow:{'Loss/classification_loss': 0.045560848,
#  'Loss/localization_loss': 0.03569627,
#  'Loss/regularization_loss': 0.1268207,
#  'Loss/total_loss': 0.20807782,
#  'learning_rate': 0.078939244}
# I0221 14:58:00.730165 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.045560848,
#  'Loss/localization_loss': 0.03569627,
#  'Loss/regularization_loss': 0.1268207,
#  'Loss/total_loss': 0.20807782,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.369s
# I0221 14:58:37.629642 8087821376 model_lib_v2.py:705] Step 4700 per-step time 0.369s
# INFO:tensorflow:{'Loss/classification_loss': 0.057165265,
#  'Loss/localization_loss': 0.013267107,
#  'Loss/regularization_loss': 0.12610972,
#  'Loss/total_loss': 0.19654208,
#  'learning_rate': 0.07887978}
# I0221 14:58:37.630292 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.057165265,
#  'Loss/localization_loss': 0.013267107,
#  'Loss/regularization_loss': 0.12610972,
#  'Loss/total_loss': 0.19654208,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.363s
# I0221 14:59:13.947098 8087821376 model_lib_v2.py:705] Step 4800 per-step time 0.363s
# INFO:tensorflow:{'Loss/classification_loss': 0.036045935,
#  'Loss/localization_loss': 0.014605648,
#  'Loss/regularization_loss': 0.12541233,
#  'Loss/total_loss': 0.17606391,
#  'learning_rate': 0.07881871}
# I0221 14:59:13.947890 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.036045935,
#  'Loss/localization_loss': 0.014605648,
#  'Loss/regularization_loss': 0.12541233,
#  'Loss/total_loss': 0.17606391,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.391s
# I0221 14:59:53.093489 8087821376 model_lib_v2.py:705] Step 4900 per-step time 0.391s
# INFO:tensorflow:{'Loss/classification_loss': 0.107149035,
#  'Loss/localization_loss': 0.045262564,
#  'Loss/regularization_loss': 0.124719724,
#  'Loss/total_loss': 0.27713132,
#  'learning_rate': 0.07875605}
# I0221 14:59:53.094388 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.107149035,
#  'Loss/localization_loss': 0.045262564,
#  'Loss/regularization_loss': 0.124719724,
#  'Loss/total_loss': 0.27713132,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.365s
# I0221 15:00:29.551027 8087821376 model_lib_v2.py:705] Step 5000 per-step time 0.365s
# INFO:tensorflow:{'Loss/classification_loss': 0.03936644,
#  'Loss/localization_loss': 0.019622762,
#  'Loss/regularization_loss': 0.124046765,
#  'Loss/total_loss': 0.18303595,
#  'learning_rate': 0.078691795}
# I0221 15:00:29.551702 8087821376 model_lib_v2.py:708] {'Loss/classification_loss': 0.03936644,
#  'Loss/localization_loss': 0.019622762,
#  'Loss/regularization_loss': 0.124046765,
#  'Loss/total_loss': 0.18303595,
#  'learning_rate': 0.078691795}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)

# %%
#!{command}

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-6')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
# !pip install --upgrade matplotlib
# Out:
# Requirement already satisfied: matplotlib in ./tfod/lib/python3.9/site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./tfod/lib/python3.9/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./tfod/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./tfod/lib/python3.9/site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./tfod/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in ./tfod/lib/python3.9/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in ./tfod/lib/python3.9/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in ./tfod/lib/python3.9/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./tfod/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in ./tfod/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./tfod/lib/python3.9/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in ./tfod/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in ./tfod/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', '99.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.5,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
#!pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(1)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    frame = cv2.flip(frame, 1) # Flip horizontally
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        # cap.release()
        # cv2.destroyAllWindows()
        # break
        break
cap.release()
cv2.destroyAllWindows()

for i in range(2):
    cv2.waitKey(10)
# Out:
# 2024-02-21 12:56:24.579 python3[9401:3751784] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.

# %% [markdown]
# ## 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
